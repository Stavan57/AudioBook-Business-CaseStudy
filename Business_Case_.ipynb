# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn import preprocessing
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Audiobooks_data.csv', header=None)
data.columns = [
    'ID', 'Book_Length_Minutes', 'Book_Length_Minutes.1', 'Book_Rating',
    'Book_Rating.1', 'Listens', 'Price', 'Price_Per_Minute', 'Total_Seconds_Listened',
    'Completed', 'Subscription_Renewed', 'Churn']

# %%
# Drop the ID column
data = data.drop(columns=['ID'])

# Check for missing values
print(data.isnull().sum())
# Out:
# Book_Length_Minutes       0
# Book_Length_Minutes.1     0
# Book_Rating               0
# Book_Rating.1             0
# Listens                   0
# Price                     0
# Price_Per_Minute          0
# Total_Seconds_Listened    0
# Completed                 0
# Subscription_Renewed      0
# Churn                     0
# dtype: int64

# %%
# Feature scaling
scaler = preprocessing.StandardScaler()
scaled_data = scaler.fit_transform(data.drop(columns=['Churn']))
targets = data['Churn'].values

# Split data into training, validation, and test sets
shuffled_indices = np.arange(scaled_data.shape[0])
np.random.shuffle(shuffled_indices)

shuffled_inputs = scaled_data[shuffled_indices]
shuffled_targets = targets[shuffled_indices]

# %%
sample_count = shuffled_inputs.shape[0]
train_samples = int(0.8 * sample_count)
validation_samples = int(0.1 * sample_count)
test_samples = sample_count - train_samples - validation_samples

# %%
train_inputs = shuffled_inputs[:train_samples]
train_targets = shuffled_targets[:train_samples]

validation_inputs = shuffled_inputs[train_samples:train_samples+validation_samples]
validation_targets = shuffled_targets[train_samples:train_samples+validation_samples]

test_inputs = shuffled_inputs[train_samples+validation_samples:]
test_targets = shuffled_targets[train_samples+validation_samples:]

# %%
# Define the model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(train_inputs.shape[1],)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(
    train_inputs, train_targets,
    epochs=100,
    batch_size=32,
    validation_data=(validation_inputs, validation_targets),
    verbose=2)
# Out:
# Epoch 1/100
# 353/353 - 2s - loss: 0.4434 - accuracy: 0.8311 - val_loss: 0.3005 - val_accuracy: 0.8984 - 2s/epoch - 6ms/step
# Epoch 2/100
# 353/353 - 1s - loss: 0.3310 - accuracy: 0.8841 - val_loss: 0.2675 - val_accuracy: 0.9048 - 684ms/epoch - 2ms/step
# Epoch 3/100
# 353/353 - 1s - loss: 0.3045 - accuracy: 0.8913 - val_loss: 0.2575 - val_accuracy: 0.9062 - 837ms/epoch - 2ms/step
# Epoch 4/100
# 353/353 - 1s - loss: 0.2909 - accuracy: 0.8925 - val_loss: 0.2453 - val_accuracy: 0.9105 - 979ms/epoch - 3ms/step
# Epoch 5/100
# 353/353 - 1s - loss: 0.2799 - accuracy: 0.8970 - val_loss: 0.2384 - val_accuracy: 0.9105 - 1s/epoch - 3ms/step
# Epoch 6/100
# 353/353 - 1s - loss: 0.2729 - accuracy: 0.8989 - val_loss: 0.2323 - val_accuracy: 0.9148 - 1s/epoch - 3ms/step
# Epoch 7/100
# 353/353 - 1s - loss: 0.2641 - accuracy: 0.8988 - val_loss: 0.2298 - val_accuracy: 0.9112 - 994ms/epoch - 3ms/step
# Epoch 8/100
# 353/353 - 1s - loss: 0.2645 - accuracy: 0.9007 - val_loss: 0.2276 - val_accuracy: 0.9148 - 679ms/epoch - 2ms/step
# Epoch 9/100
# 353/353 - 1s - loss: 0.2597 - accuracy: 0.9016 - val_loss: 0.2241 - val_accuracy: 0.9190 - 658ms/epoch - 2ms/step
# Epoch 10/100
# 353/353 - 1s - loss: 0.2543 - accuracy: 0.9022 - val_loss: 0.2231 - val_accuracy: 0.9176 - 635ms/epoch - 2ms/step
# Epoch 11/100
# 353/353 - 1s - loss: 0.2543 - accuracy: 0.9034 - val_loss: 0.2216 - val_accuracy: 0.9176 - 642ms/epoch - 2ms/step
# Epoch 12/100
# 353/353 - 1s - loss: 0.2488 - accuracy: 0.9034 - val_loss: 0.2185 - val_accuracy: 0.9162 - 657ms/epoch - 2ms/step
# Epoch 13/100
# 353/353 - 1s - loss: 0.2478 - accuracy: 0.9035 - val_loss: 0.2168 - val_accuracy: 0.9183 - 634ms/epoch - 2ms/step
# Epoch 14/100
# 353/353 - 1s - loss: 0.2505 - accuracy: 0.9031 - val_loss: 0.2176 - val_accuracy: 0.9162 - 784ms/epoch - 2ms/step
# Epoch 15/100
# 353/353 - 1s - loss: 0.2445 - accuracy: 0.9041 - val_loss: 0.2152 - val_accuracy: 0.9183 - 782ms/epoch - 2ms/step
# Epoch 16/100
# 353/353 - 1s - loss: 0.2427 - accuracy: 0.9057 - val_loss: 0.2166 - val_accuracy: 0.9197 - 664ms/epoch - 2ms/step
# Epoch 17/100
# 353/353 - 1s - loss: 0.2413 - accuracy: 0.9057 - val_loss: 0.2147 - val_accuracy: 0.9169 - 639ms/epoch - 2ms/step
# Epoch 18/100
# 353/353 - 1s - loss: 0.2449 - accuracy: 0.9036 - val_loss: 0.2153 - val_accuracy: 0.9183 - 644ms/epoch - 2ms/step
# Epoch 19/100
# 353/353 - 1s - loss: 0.2430 - accuracy: 0.9047 - val_loss: 0.2146 - val_accuracy: 0.9183 - 643ms/epoch - 2ms/step
# Epoch 20/100
# 353/353 - 1s - loss: 0.2437 - accuracy: 0.9046 - val_loss: 0.2140 - val_accuracy: 0.9169 - 659ms/epoch - 2ms/step
# Epoch 21/100
# 353/353 - 1s - loss: 0.2384 - accuracy: 0.9056 - val_loss: 0.2138 - val_accuracy: 0.9169 - 729ms/epoch - 2ms/step
# Epoch 22/100
# 353/353 - 1s - loss: 0.2431 - accuracy: 0.9045 - val_loss: 0.2146 - val_accuracy: 0.9176 - 754ms/epoch - 2ms/step
# Epoch 23/100
# 353/353 - 1s - loss: 0.2377 - accuracy: 0.9077 - val_loss: 0.2129 - val_accuracy: 0.9169 - 975ms/epoch - 3ms/step
# Epoch 24/100
# 353/353 - 1s - loss: 0.2368 - accuracy: 0.9060 - val_loss: 0.2119 - val_accuracy: 0.9183 - 935ms/epoch - 3ms/step
# Epoch 25/100
# 353/353 - 1s - loss: 0.2392 - accuracy: 0.9060 - val_loss: 0.2112 - val_accuracy: 0.9162 - 934ms/epoch - 3ms/step
# Epoch 26/100
# 353/353 - 1s - loss: 0.2371 - accuracy: 0.9073 - val_loss: 0.2099 - val_accuracy: 0.9197 - 1s/epoch - 3ms/step
# Epoch 27/100
# 353/353 - 1s - loss: 0.2367 - accuracy: 0.9062 - val_loss: 0.2133 - val_accuracy: 0.9183 - 813ms/epoch - 2ms/step
# Epoch 28/100
# 353/353 - 1s - loss: 0.2365 - accuracy: 0.9055 - val_loss: 0.2105 - val_accuracy: 0.9176 - 632ms/epoch - 2ms/step
# Epoch 29/100
# 353/353 - 1s - loss: 0.2345 - accuracy: 0.9066 - val_loss: 0.2107 - val_accuracy: 0.9190 - 672ms/epoch - 2ms/step
# Epoch 30/100
# 353/353 - 1s - loss: 0.2373 - accuracy: 0.9051 - val_loss: 0.2108 - val_accuracy: 0.9176 - 663ms/epoch - 2ms/step
# Epoch 31/100
# 353/353 - 1s - loss: 0.2331 - accuracy: 0.9081 - val_loss: 0.2101 - val_accuracy: 0.9169 - 631ms/epoch - 2ms/step
# Epoch 32/100
# 353/353 - 1s - loss: 0.2354 - accuracy: 0.9073 - val_loss: 0.2120 - val_accuracy: 0.9183 - 672ms/epoch - 2ms/step
# Epoch 33/100
# 353/353 - 1s - loss: 0.2343 - accuracy: 0.9065 - val_loss: 0.2100 - val_accuracy: 0.9176 - 633ms/epoch - 2ms/step
# Epoch 34/100
# 353/353 - 1s - loss: 0.2346 - accuracy: 0.9070 - val_loss: 0.2103 - val_accuracy: 0.9183 - 656ms/epoch - 2ms/step
# Epoch 35/100
# 353/353 - 1s - loss: 0.2329 - accuracy: 0.9073 - val_loss: 0.2095 - val_accuracy: 0.9183 - 668ms/epoch - 2ms/step
# Epoch 36/100
# 353/353 - 1s - loss: 0.2355 - accuracy: 0.9068 - val_loss: 0.2102 - val_accuracy: 0.9190 - 635ms/epoch - 2ms/step
# Epoch 37/100
# 353/353 - 1s - loss: 0.2314 - accuracy: 0.9081 - val_loss: 0.2082 - val_accuracy: 0.9183 - 657ms/epoch - 2ms/step
# Epoch 38/100
# 353/353 - 1s - loss: 0.2357 - accuracy: 0.9060 - val_loss: 0.2091 - val_accuracy: 0.9205 - 661ms/epoch - 2ms/step
# Epoch 39/100
# 353/353 - 1s - loss: 0.2334 - accuracy: 0.9081 - val_loss: 0.2097 - val_accuracy: 0.9190 - 634ms/epoch - 2ms/step
# Epoch 40/100
# 353/353 - 1s - loss: 0.2320 - accuracy: 0.9093 - val_loss: 0.2076 - val_accuracy: 0.9205 - 645ms/epoch - 2ms/step
# Epoch 41/100
# 353/353 - 1s - loss: 0.2377 - accuracy: 0.9089 - val_loss: 0.2098 - val_accuracy: 0.9197 - 653ms/epoch - 2ms/step
# Epoch 42/100
# 353/353 - 1s - loss: 0.2326 - accuracy: 0.9071 - val_loss: 0.2130 - val_accuracy: 0.9162 - 811ms/epoch - 2ms/step
# Epoch 43/100
# 353/353 - 1s - loss: 0.2330 - accuracy: 0.9077 - val_loss: 0.2114 - val_accuracy: 0.9205 - 1s/epoch - 3ms/step
# Epoch 44/100
# 353/353 - 1s - loss: 0.2345 - accuracy: 0.9082 - val_loss: 0.2078 - val_accuracy: 0.9212 - 1s/epoch - 3ms/step
# Epoch 45/100
# 353/353 - 1s - loss: 0.2330 - accuracy: 0.9073 - val_loss: 0.2108 - val_accuracy: 0.9190 - 1s/epoch - 3ms/step
# Epoch 46/100
# 353/353 - 1s - loss: 0.2308 - accuracy: 0.9076 - val_loss: 0.2092 - val_accuracy: 0.9190 - 946ms/epoch - 3ms/step
# Epoch 47/100
# 353/353 - 1s - loss: 0.2316 - accuracy: 0.9071 - val_loss: 0.2126 - val_accuracy: 0.9190 - 664ms/epoch - 2ms/step
# Epoch 48/100
# 353/353 - 1s - loss: 0.2305 - accuracy: 0.9087 - val_loss: 0.2095 - val_accuracy: 0.9183 - 671ms/epoch - 2ms/step
# Epoch 49/100
# 353/353 - 1s - loss: 0.2319 - accuracy: 0.9081 - val_loss: 0.2096 - val_accuracy: 0.9197 - 654ms/epoch - 2ms/step
# Epoch 50/100
# 353/353 - 1s - loss: 0.2313 - accuracy: 0.9081 - val_loss: 0.2116 - val_accuracy: 0.9183 - 659ms/epoch - 2ms/step
# Epoch 51/100
# 353/353 - 1s - loss: 0.2312 - accuracy: 0.9071 - val_loss: 0.2089 - val_accuracy: 0.9212 - 668ms/epoch - 2ms/step
# Epoch 52/100
# 353/353 - 1s - loss: 0.2310 - accuracy: 0.9079 - val_loss: 0.2064 - val_accuracy: 0.9212 - 641ms/epoch - 2ms/step
# Epoch 53/100
# 353/353 - 1s - loss: 0.2292 - accuracy: 0.9076 - val_loss: 0.2094 - val_accuracy: 0.9226 - 687ms/epoch - 2ms/step
# Epoch 54/100
# 353/353 - 1s - loss: 0.2309 - accuracy: 0.9086 - val_loss: 0.2082 - val_accuracy: 0.9197 - 738ms/epoch - 2ms/step
# Epoch 55/100
# 353/353 - 1s - loss: 0.2294 - accuracy: 0.9085 - val_loss: 0.2098 - val_accuracy: 0.9183 - 658ms/epoch - 2ms/step
# Epoch 56/100
# 353/353 - 1s - loss: 0.2303 - accuracy: 0.9104 - val_loss: 0.2084 - val_accuracy: 0.9183 - 643ms/epoch - 2ms/step
# Epoch 57/100
# 353/353 - 1s - loss: 0.2273 - accuracy: 0.9097 - val_loss: 0.2114 - val_accuracy: 0.9190 - 648ms/epoch - 2ms/step
# Epoch 58/100
# 353/353 - 1s - loss: 0.2313 - accuracy: 0.9078 - val_loss: 0.2082 - val_accuracy: 0.9197 - 654ms/epoch - 2ms/step
# Epoch 59/100
# 353/353 - 1s - loss: 0.2312 - accuracy: 0.9078 - val_loss: 0.2101 - val_accuracy: 0.9176 - 649ms/epoch - 2ms/step
# Epoch 60/100
# 353/353 - 1s - loss: 0.2295 - accuracy: 0.9086 - val_loss: 0.2083 - val_accuracy: 0.9197 - 659ms/epoch - 2ms/step
# Epoch 61/100
# 353/353 - 1s - loss: 0.2295 - accuracy: 0.9083 - val_loss: 0.2083 - val_accuracy: 0.9183 - 825ms/epoch - 2ms/step
# Epoch 62/100
# 353/353 - 1s - loss: 0.2332 - accuracy: 0.9104 - val_loss: 0.2096 - val_accuracy: 0.9205 - 931ms/epoch - 3ms/step
# Epoch 63/100
# 353/353 - 1s - loss: 0.2282 - accuracy: 0.9089 - val_loss: 0.2113 - val_accuracy: 0.9169 - 981ms/epoch - 3ms/step
# Epoch 64/100
# 353/353 - 1s - loss: 0.2302 - accuracy: 0.9075 - val_loss: 0.2110 - val_accuracy: 0.9183 - 1s/epoch - 3ms/step
# Epoch 65/100
# 353/353 - 1s - loss: 0.2306 - accuracy: 0.9082 - val_loss: 0.2105 - val_accuracy: 0.9176 - 1s/epoch - 3ms/step
# Epoch 66/100
# 353/353 - 1s - loss: 0.2304 - accuracy: 0.9091 - val_loss: 0.2100 - val_accuracy: 0.9197 - 661ms/epoch - 2ms/step
# Epoch 67/100
# 353/353 - 1s - loss: 0.2283 - accuracy: 0.9096 - val_loss: 0.2096 - val_accuracy: 0.9197 - 637ms/epoch - 2ms/step
# Epoch 68/100
# 353/353 - 1s - loss: 0.2291 - accuracy: 0.9084 - val_loss: 0.2062 - val_accuracy: 0.9197 - 648ms/epoch - 2ms/step
# Epoch 69/100
# 353/353 - 1s - loss: 0.2315 - accuracy: 0.9070 - val_loss: 0.2093 - val_accuracy: 0.9197 - 747ms/epoch - 2ms/step
# Epoch 70/100
# 353/353 - 1s - loss: 0.2305 - accuracy: 0.9088 - val_loss: 0.2084 - val_accuracy: 0.9205 - 637ms/epoch - 2ms/step
# Epoch 71/100
# 353/353 - 1s - loss: 0.2351 - accuracy: 0.9079 - val_loss: 0.2100 - val_accuracy: 0.9183 - 665ms/epoch - 2ms/step
# Epoch 72/100
# 353/353 - 1s - loss: 0.2282 - accuracy: 0.9083 - val_loss: 0.2085 - val_accuracy: 0.9190 - 631ms/epoch - 2ms/step
# Epoch 73/100
# 353/353 - 1s - loss: 0.2304 - accuracy: 0.9084 - val_loss: 0.2082 - val_accuracy: 0.9212 - 695ms/epoch - 2ms/step
# Epoch 74/100
# 353/353 - 1s - loss: 0.2306 - accuracy: 0.9084 - val_loss: 0.2085 - val_accuracy: 0.9197 - 650ms/epoch - 2ms/step
# Epoch 75/100
# 353/353 - 1s - loss: 0.2281 - accuracy: 0.9087 - val_loss: 0.2094 - val_accuracy: 0.9190 - 646ms/epoch - 2ms/step
# Epoch 76/100
# 353/353 - 1s - loss: 0.2291 - accuracy: 0.9093 - val_loss: 0.2093 - val_accuracy: 0.9197 - 671ms/epoch - 2ms/step
# Epoch 77/100
# 353/353 - 1s - loss: 0.2294 - accuracy: 0.9101 - val_loss: 0.2107 - val_accuracy: 0.9190 - 672ms/epoch - 2ms/step
# Epoch 78/100
# 353/353 - 1s - loss: 0.2316 - accuracy: 0.9084 - val_loss: 0.2076 - val_accuracy: 0.9205 - 649ms/epoch - 2ms/step
# Epoch 79/100
# 353/353 - 1s - loss: 0.2298 - accuracy: 0.9098 - val_loss: 0.2082 - val_accuracy: 0.9197 - 660ms/epoch - 2ms/step
# Epoch 80/100
# 353/353 - 1s - loss: 0.2278 - accuracy: 0.9098 - val_loss: 0.2076 - val_accuracy: 0.9197 - 647ms/epoch - 2ms/step
# Epoch 81/100
# 353/353 - 1s - loss: 0.2279 - accuracy: 0.9091 - val_loss: 0.2082 - val_accuracy: 0.9197 - 1s/epoch - 3ms/step
# Epoch 82/100
# 353/353 - 1s - loss: 0.2284 - accuracy: 0.9084 - val_loss: 0.2083 - val_accuracy: 0.9190 - 963ms/epoch - 3ms/step
# Epoch 83/100
# 353/353 - 1s - loss: 0.2269 - accuracy: 0.9112 - val_loss: 0.2080 - val_accuracy: 0.9205 - 1s/epoch - 3ms/step
# Epoch 84/100
# 353/353 - 1s - loss: 0.2292 - accuracy: 0.9088 - val_loss: 0.2084 - val_accuracy: 0.9205 - 944ms/epoch - 3ms/step
# Epoch 85/100
# 353/353 - 1s - loss: 0.2301 - accuracy: 0.9082 - val_loss: 0.2107 - val_accuracy: 0.9190 - 1s/epoch - 3ms/step
# Epoch 86/100
# 353/353 - 1s - loss: 0.2296 - accuracy: 0.9081 - val_loss: 0.2084 - val_accuracy: 0.9183 - 648ms/epoch - 2ms/step
# Epoch 87/100
# 353/353 - 1s - loss: 0.2270 - accuracy: 0.9109 - val_loss: 0.2084 - val_accuracy: 0.9205 - 657ms/epoch - 2ms/step
# Epoch 88/100
# 353/353 - 1s - loss: 0.2275 - accuracy: 0.9082 - val_loss: 0.2098 - val_accuracy: 0.9190 - 644ms/epoch - 2ms/step
# Epoch 89/100
# 353/353 - 1s - loss: 0.2287 - accuracy: 0.9083 - val_loss: 0.2090 - val_accuracy: 0.9190 - 652ms/epoch - 2ms/step
# Epoch 90/100
# 353/353 - 1s - loss: 0.2301 - accuracy: 0.9098 - val_loss: 0.2090 - val_accuracy: 0.9190 - 663ms/epoch - 2ms/step
# Epoch 91/100
# 353/353 - 1s - loss: 0.2292 - accuracy: 0.9094 - val_loss: 0.2099 - val_accuracy: 0.9212 - 648ms/epoch - 2ms/step
# Epoch 92/100
# 353/353 - 1s - loss: 0.2306 - accuracy: 0.9091 - val_loss: 0.2063 - val_accuracy: 0.9212 - 656ms/epoch - 2ms/step
# Epoch 93/100
# 353/353 - 1s - loss: 0.2260 - accuracy: 0.9110 - val_loss: 0.2090 - val_accuracy: 0.9219 - 638ms/epoch - 2ms/step
# Epoch 94/100
# 353/353 - 1s - loss: 0.2282 - accuracy: 0.9086 - val_loss: 0.2086 - val_accuracy: 0.9197 - 655ms/epoch - 2ms/step
# Epoch 95/100
# 353/353 - 1s - loss: 0.2296 - accuracy: 0.9081 - val_loss: 0.2090 - val_accuracy: 0.9197 - 649ms/epoch - 2ms/step
# Epoch 96/100
# 353/353 - 1s - loss: 0.2257 - accuracy: 0.9112 - val_loss: 0.2083 - val_accuracy: 0.9197 - 645ms/epoch - 2ms/step
# Epoch 97/100
# 353/353 - 1s - loss: 0.2284 - accuracy: 0.9094 - val_loss: 0.2083 - val_accuracy: 0.9197 - 660ms/epoch - 2ms/step
# Epoch 98/100
# 353/353 - 1s - loss: 0.2306 - accuracy: 0.9081 - val_loss: 0.2089 - val_accuracy: 0.9205 - 656ms/epoch - 2ms/step
# Epoch 99/100
# 353/353 - 1s - loss: 0.2256 - accuracy: 0.9115 - val_loss: 0.2073 - val_accuracy: 0.9219 - 651ms/epoch - 2ms/step
# Epoch 100/100
# 353/353 - 1s - loss: 0.2295 - accuracy: 0.9097 - val_loss: 0.2121 - val_accuracy: 0.9155 - 672ms/epoch - 2ms/step

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
print('Test accuracy:', test_accuracy)
# Out:
# 45/45 [==============================] - 1s 3ms/step - loss: 0.2272 - accuracy: 0.9077
# Test accuracy: 0.9077360033988953
